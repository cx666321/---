# %% [markdown]
# <a href="https://colab.research.google.com/github/cx666321/jiqixuexi/blob/main/test02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("name:CHEN XI,phone number: 010-8292-7127,student id:50250336")
# Out:
# name:CHEN XI,phone number: 010-8292-7127,student id:50250336
